# %%
import sys
sys.path.insert(1, '../src')
from utils import *

# %% [markdown]
# Useful resources:
#
# https://readthedocs.org/projects/pandas-datareader/downloads/pdf/latest/
#
# https://www.investopedia.com/terms/c/consumerpriceindex.asp
#
# https://www.investopedia.com/insights/understanding-consumer-confidence-index/
#
# https://fred.stlouisfed.org/series

# %%
compute_stats(['EXPE', 'GOOG', 'MSFT', 'AAPL', 'BB', 'JNPR', 'BRK-B', 'BRK-A'])
# Out:
#       language region quoteType  triggerable         quoteSourceName currency  \
# EXPE     en-US     US    EQUITY         True  Nasdaq Real Time Price      USD
# GOOG     en-US     US    EQUITY         True           Delayed Quote      USD
# MSFT     en-US     US    EQUITY         True           Delayed Quote      USD
# AAPL     en-US     US    EQUITY         True           Delayed Quote      USD
# BB       en-US     US    EQUITY         True           Delayed Quote      USD
# JNPR     en-US     US    EQUITY         True                     NaN      USD
# BRK-B    en-US     US    EQUITY         True           Delayed Quote      USD
# BRK-A    en-US     US    EQUITY         True                     NaN      USD
#
#        firstTradeDateMilliseconds  priceHint  postMarketChangePercent  \
# EXPE                1121932800000          2                 0.000000
# GOOG                1092902400000          2                 0.075655
# ...

# %%
compare_dollar_cost_averaging_return('SPY', start_date='2015-01-02', end_date='2019-12-31')
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-12-31  322.130005  320.149994  320.529999  321.859985  57077300
#
#              Adj Close
# Date
# 2019-12-31  321.859985
# 0.14949218742357617

# %% [markdown]
# ### Getting historic stock dividends

# %%
get_historical_data('AAPL', start_date='2019-01-02', end_date='2019-12-31', source = 'yahoo-dividends')
# Out:
#               action  value
# 2019-11-07  DIVIDEND   0.77
# 2019-08-09  DIVIDEND   0.77
# 2019-05-10  DIVIDEND   0.77
# 2019-02-08  DIVIDEND   0.73
